# %%
import glob, os
import re
from tqdm import tqdm
directory = "../Ling506TermProject/"
precisionS = "Precision"
precision = 0
recallS = "Recall"
recall = 0
f1S = "F1-Score"
f1 = 0
accuracyS = "Accuracy"
accuracy = 0

for file in glob.glob("*.txt"):
    with open(file, 'r',encoding="utf-8") as f:
        corpus1 = ""
        corpus2 = ""
        mode = ""
        print(file)
        names = file.split("_")
        corpus1 = names[0]
        corpus2 = names[2]
        mode = names[3].split(".")[0]
        print(names)
        print(corpus1)
        print(corpus2)
        print(mode)
        metrics = [next(f) for x in range(4)]
        print(metrics)
        
        precisionMetrics = metrics[0].split("\t")
        precision = precisionMetrics[1].strip()
        print(precision)
        
        recallMetrics = metrics[1].split("\t")
        recall = recallMetrics[1].strip()
        print(recall)
        
        f1Metrics = metrics[2].split("\t")
        f1 = recallMetrics[1].strip()
        print(f1)
        
        accuracyMetrics = metrics[3].split("\t")
        accuracy = accuracyMetrics[1].strip()
        print(accuracy)
        
        
#             print(line)
#             if precisionS in line:
#                 print(line[1])
#         for line in f:
#             line = line.split(" ")
#             print(line)
# Out:
# affectivetext_vs_crowdflower_multi.txt
# ['affectivetext', 'vs', 'crowdflower', 'multi.txt']
# affectivetext
# crowdflower
# multi
# ['Precision\t0.1351516119199338\n', 'Recall\t0.3506967984934087\n', 'F1-score\t0.19511121821401253\n', 'Accuracy\t0.026950176144942124\n']
# 0.1351516119199338
# 0.3506967984934087
# 0.3506967984934087
# 0.026950176144942124
# affectivetext_vs_dailydialog_multi.txt
# ['affectivetext', 'vs', 'dailydialog', 'multi.txt']
# affectivetext
# dailydialog
# multi
# ['Precision\t0.05832143021702069\n', 'Recall\t0.5817199977020738\n', 'F1-score\t0.10601420711821641\n', 'Accuracy\t0.01877081735111042\n']
# 0.05832143021702069
# 0.5817199977020738
# 0.5817199977020738
# 0.01877081735111042
# affectivetext_vs_emoint_multi.txt
# ['affectivetext', 'vs', 'emoint', 'multi.txt']
# affectivetext
# emoint
# multi
# ['Precision\t0.2605894669028829\n', 'Recall\t0.2278231484088989\n', 'F1-score\t0.24310720456765084\n', 'Accuracy\t0.1829062235989862\n']
# 0.2605894669028829
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
uniform_data = np.random.rand(10, 12)
fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flights, annot=True, fmt="d")

# %%
import pandas as pd
import json
df = pd.DataFrame([['a', 'b'], ['c', 'd']],
                  index=['row 1', 'row 2'],
                  columns=['col 1', 'col 2'])
df.to_json(orient='records')
# data = json.loads("../Ling506TermProject/affectivetext_vs_crowdflower_multi.json")
df2 = pd.read_json("../Ling506TermProject/affectivetext_vs_crowdflower_multi.json", orient='index')
df2.columns = ['affectivetext_vs_crowdflower']
# print(df2)
df3 = pd.read_json("../Ling506TermProject/affectivetext_vs_emotion-cause_multi.json", orient='index')
df3.columns = ['affectivetext_vs_emotion-cause']
# print(df3)
# for col in df2.columns: 
#     print(col)
# print(df2)
# "affectivetext_vs_crowdflower"

df4 = pd.concat([df2,df3],axis=1,sort=False)
df4
# Out:
#                           affectivetext_vs_crowdflower  \
# precision                                     0.135152
# recall                                        0.350697
# f1                                            0.195111
# accuracy                                     0.0269502
# name                affectivetext_vs_crowdflower_multi
# anger_precision                              0.0772532
# anger_recall                                 0.0126671
# anger_accuracy                                0.959285
# anger_f1                                     0.0217654
# anger_tp                                            18
# anger_tn                                         38104
# anger_fp                                           215
# anger_fn                                          1403
# joy_precision                                 0.248603
# joy_recall                                    0.685249
# joy_accuracy                                  0.446452
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
uniform_data = np.random.rand(10, 12)
fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
sns.heatmap(uniform_data, annot=True, linewidths=.5, ax=ax)

# %%
import matplotlib.pyplot as plt
import pandas as pd

def heatmap_using_seaborn(data):
    import seaborn as sns; sns.set()
    ax = sns.heatmap(data)
    plt.show()

def heatmap_using_pandas(data):
    import numpy as np ; np.random.seed(0)
    plt.pcolor(data)
    plt.yticks(np.arange(0.5, len(data.index), 1), data.index)
    plt.xticks(np.arange(0.5, len(data.columns), 1), data.columns)
    plt.show()

data = pd.DataFrame({
    'left':   [0,   10, 20, 30, 33, 40,  0, 10],
    'center': [100, 80, 60, 40, 34, 20, 10, 20],
    'right':  [0,   10, 20, 30, 33, 40, 90, 70],
})

print(data)
# pick one, the seaborn one is better, but needs seaborn package
heatmap_using_pandas(data)
heatmap_using_seaborn(data)
# Out:
#    left  center  right
# 0     0     100      0
# 1    10      80     10
# 2    20      60     20
# 3    30      40     30
# 4    33      34     33
# 5    40      20     40
# 6     0      10     90
# 7    10      20     70
